# %% [markdown]
# <a href="https://colab.research.google.com/github/Kunal988-gif/DataScience/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dct  = {
    "name ": "Kunal",
    "roll no" : 44,
    "occupation" : "Student",
    "place" : "Indore",
    "college": "MIRAI"
}

dct['id'] = 12
print(dct)

del dct["place"]
print(dct)
# Out:
# {'name ': 'Kunal', 'roll no': 44, 'occupation': 'Student', 'place': 'Indore', 'college': 'MIRAI', 'id': 12}
# {'name ': 'Kunal', 'roll no': 44, 'occupation': 'Student', 'college': 'MIRAI', 'id': 12}
